# %%
import pandas as pd
import plotly.graph_objects as go
import folium

# %%
df = pd.read_csv('MUESTRA_CENSO_PROV_BCN_20230215.csv', sep = '|', on_bad_lines='skip')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504986 entries, 0 to 504985
# Columns: 131 entries, ADN_OID_CENTRO to FACTU_EST
# dtypes: float64(56), int64(32), object(43)
# memory usage: 504.7+ MB

# %%
df2 = pd.read_csv('censo_bcn_Excel_empresas_20210111.csv')
df2.info()
# Out:
# C:\Users\rubyc\AppData\Local\Temp\ipykernel_44416\2550974486.py:1: DtypeWarning: Columns (3,4,6,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('censo_bcn_Excel_empresas_20210111.csv')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 728959 entries, 0 to 728958
# Data columns (total 54 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   PERIODO                         728959 non-null  int64
#  1   OID_EMPRESA                     728959 non-null  int64
#  2   OID_CENTRO                      728959 non-null  int64
#  3   SSCC                            728959 non-null  object
#  4   DIST_COD                        728959 non-null  object
#  5   DISTRITO                        728959 non-null  object
#  6   MUNICIPIO_COD                   728959 non-null  object
#  7   MUNICIPIO                       728959 non-null  object
# ...

# %%
df_code = df2[['GCNAE_COD','GCNAE','CCNAE_COD','CCNAE','SCNAE_COD','SCNAE']]

# %%
df_code = df_code.groupby(['GCNAE_COD','GCNAE','CCNAE_COD','CCNAE','SCNAE_COD','SCNAE'])[['GCNAE_COD','GCNAE','CCNAE_COD','CCNAE','SCNAE_COD','SCNAE']]

# %%
df_code.head()
# Out:
#   GCNAE_COD                                              GCNAE CCNAE_COD  \
# 0         I                                     I - Hosteleria        56
# 1         M  M - Actividades profesionales, científicas y t...        71
# 2         M  M - Actividades profesionales, científicas y t...        74
# 3         M  M - Actividades profesionales, científicas y t...        71
# 4         I                                     I - Hosteleria        56
#
#                                                CCNAE SCNAE_COD  \
# 0                56 - Servicios de comidas y bebidas      5610
# 1  71 - Servicios técnicos de arquitectura e inge...       NaN
# 2  74 - Otras actividades profesionales, científi...      7490
# 3  71 - Servicios técnicos de arquitectura e inge...       NaN
# 4                56 - Servicios de comidas y bebidas      5629
#
#                                                SCNAE
# 0           5610 - Restaurantes y puestos de comidas
# ...

# %%
df_code = df_code.dropna(subset = 'SCNAE_COD')
df_code.info()
# df.dropna(subset = ['column1_name', 'column2_name', 'column3_name'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 700997 entries, 0 to 728958
# Data columns (total 6 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   GCNAE_COD  700997 non-null  object
#  1   GCNAE      700997 non-null  object
#  2   CCNAE_COD  700997 non-null  object
#  3   CCNAE      700997 non-null  object
#  4   SCNAE_COD  700997 non-null  object
#  5   SCNAE      700997 non-null  object
# dtypes: object(6)
# memory usage: 37.4+ MB

# %%
df_code = df_code.drop_duplicates(subset = ['GCNAE_COD', 'CCNAE_COD', 'SCNAE_COD'])
df_code.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 561 entries, 0 to 696497
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   GCNAE_COD  561 non-null    object
#  1   GCNAE      561 non-null    object
#  2   CCNAE_COD  561 non-null    object
#  3   CCNAE      561 non-null    object
#  4   SCNAE_COD  561 non-null    object
#  5   SCNAE      561 non-null    object
# dtypes: object(6)
# memory usage: 30.7+ KB

# %%
df_code
# Out:
#        GCNAE_COD                                              GCNAE CCNAE_COD  \
# 0              I                                     I - Hosteleria        56
# 2              M  M - Actividades profesionales, científicas y t...        74
# 4              I                                     I - Hosteleria        56
# 5              I                                     I - Hosteleria        56
# 7              P                                      P - Educación        85
# ...          ...                                                ...       ...
# 475573         C                        C - Industria manufacturera        23
# 525791         B                         B - Industrias extractivas         5
# 535839         B                         B - Industrias extractivas         8
# 612899         R  R - Actividades artísticas, recreativas y de e...        91
# 696497         F                                   F - Construcción        42
#
# ...

# %%
df_code[df_code['GCNAE_COD'] == 'C']
# Out:
#        GCNAE_COD                        GCNAE CCNAE_COD  \
# 8              C  C - Industria manufacturera        18
# 25             C  C - Industria manufacturera        32
# 35             C  C - Industria manufacturera        32
# 58             C  C - Industria manufacturera        14
# 163            C  C - Industria manufacturera        10
# ...          ...                          ...       ...
# 323627         C  C - Industria manufacturera        19
# 330290         C  C - Industria manufacturera        20
# 343342         C  C - Industria manufacturera        10
# 393933         C  C - Industria manufacturera        32
# 475573         C  C - Industria manufacturera        23
#
#                                                     CCNAE SCNAE_COD  \
# 8       18 - Artes gráficas y reproducción de soportes...      1812
# 25                   32 - Otras industrias manufactureras      3299
# 35                   32 - Otras industrias manufactureras      3212
# ...

# %%
#df_code.to_csv('CNAE_CODE.CSV')
